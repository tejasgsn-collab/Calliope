# %%
import ast

# %%
code = "x = 5"
tree = ast.parse(code)

# %%
print(ast.dump(tree, indent=4))

# %%
tree = ast.parse("""
x = 5
print(x + 2)
""")

for node in tree.body:
    print(type(node))

# %%
for node in tree.body:
    print(ast.dump(node, indent=4))

# %%
tricode = "x = 5"
tree = ast.parse(tricode)
